# %%
#importa pandas e numpy

import pandas as pd
import numpy as np

# %%
#leggi con il csv il file ./heart_disesases.csv

df = pd.read_csv('./heart_disease.csv')

#stampa le prime 5 righe del dataset

df.head(5)
# Out:
#     Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 0  56.0    Male           153.0              155.0            High     Yes
# 1  69.0  Female           146.0              286.0            High      No
# 2  46.0    Male           126.0              216.0             Low      No
# 3  32.0  Female           122.0              293.0            High     Yes
# 4  60.0    Male           166.0              242.0             Low     Yes
#
#   Family_Heart_Disease Diabetes        BMI High_Blood_Pressure  ...  \
# 0                  Yes       No  24.991591                 Yes  ...
# 1                  Yes      Yes  25.221799                  No  ...
# 2                   No       No  29.855447                  No  ...
# 3                  Yes       No  24.130477                 Yes  ...
# 4                  Yes      Yes  20.486289                 Yes  ...
#
#   High_LDL_Cholesterol Alcohol_Consumption Stress_Level Sleep_Hours  \
# ...

# %%
#stampa i dati relativi ai fumatori

df[df['Smoking'] == "Yes"]
# Out:
#        Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# 5     25.0    Male           152.0              257.0             Low     Yes
# 6     78.0  Female           121.0              175.0            High     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9994  73.0  Female           144.0              191.0          Medium     Yes
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
# i dati relativi all'età e pressione delle donne che soffrono di diabete fai riferimento ai dati caricati

df[(df['Gender'] == 'Female') & (df['Diabetes'] == 'Yes')]
# Out:
#        Age  Gender  Blood_Pressure  Cholesterol_Level Exercise_Habits Smoking  \
# 1     69.0  Female           146.0              286.0            High      No
# 6     78.0  Female           121.0              175.0            High     Yes
# 7     38.0  Female           161.0              187.0             Low     Yes
# 8     56.0  Female           135.0              291.0             Low      No
# 11    40.0  Female           134.0              296.0            High      No
# ...    ...     ...             ...                ...             ...     ...
# 9990  55.0  Female           131.0              160.0            High     Yes
# 9991  41.0  Female           160.0              241.0          Medium      No
# 9993  27.0  Female           153.0              188.0          Medium      No
# 9994  73.0  Female           144.0              191.0          Medium     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %%
#numero totale di fumatori maschi

df[df['Gender'] == 'Male']['Smoking'].value_counts()
# Out:
# Smoking
# Yes    2538
# No     2455
# Name: count, dtype: int64
