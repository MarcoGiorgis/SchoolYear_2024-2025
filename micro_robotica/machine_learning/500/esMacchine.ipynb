# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("./Used_fiat_500_in_Italy_dataset.csv")
data.head(10)
# Out:
#     model  engine_power transmission  age_in_days      km  previous_owners  \
# 0     pop            69       manual         4474   56779                2
# 1  lounge            69       manual         2708  160000                1
# 2  lounge            69    automatic         3470  170000                2
# 3   sport            69       manual         3288  132000                2
# 4   sport            69       manual         3712  124490                2
# 5  lounge            69       manual         3684   91000                1
# 6  lounge            69    automatic         4353   90068                1
# 7     pop            69       manual         4414   69000                2
# 8  lounge            69    automatic         4322  117000                1
# 9  lounge            99       manual         4566   78000                1
#
#          lat       lon  price
# 0  45.071079   7.46403   4490
# 1  45.069679   7.70492   4500
# 2  45.514599   9.28434   4500
# ...

# %%
from sklearn.preprocessing import LabelEncoder
leModel=LabelEncoder()
leTransmission=LabelEncoder()

# %%
modelEnc=leModel.fit_transform(data["model"])
trasmissionEnc=leTransmission.fit_transform(data["transmission"])

# %%
data["modelEnc"]=modelEnc
data["transmissionEnc"]=trasmissionEnc
data.head()
# Out:
#     model  engine_power transmission  age_in_days      km  previous_owners  \
# 0     pop            69       manual         4474   56779                2
# 1  lounge            69       manual         2708  160000                1
# 2  lounge            69    automatic         3470  170000                2
# 3   sport            69       manual         3288  132000                2
# 4   sport            69       manual         3712  124490                2
#
#          lat       lon  price  modelEnc  transmissionEnc
# 0  45.071079   7.46403   4490         1                1
# 1  45.069679   7.70492   4500         0                1
# 2  45.514599   9.28434   4500         0                0
# 3  41.903221  12.49565   4700         2                1
# 4  45.532661   9.03892   4790         2                1

# %% [markdown]
# suddisione dei dati in train e test

# %%
features=["engine_power", "age_in_days", "km", "previous_owners", "lat", "lon", "modelEnc", "transmissionEnc"]
target=["price"]

# %%
from sklearn.model_selection import train_test_split
X=data[features].to_numpy() 
y=data[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.8440088818018046

# %%
#esporto il modello
import joblib
joblib.dump(model, 'my_mlp.joblib')
joblib.dump(leModel, 'leModel.joblib')
joblib.dump(leTransmission, 'leTransmission.joblib')
# Out:
# ['leTransmission.joblib']
